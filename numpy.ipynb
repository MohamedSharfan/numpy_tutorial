# %%
import numpy as np
from numpy import dtype

# %%
rev_q1 = np.array([10,12,9])
rev_q1.ndim
# Out:
# 1

# %%
rev = np.array([[10,12,9],[15,11,13]])
rev
# Out:
# array([[10, 12,  9],
#        [15, 11, 13]])

# %%
rev[1,2]
# Out:
# np.int64(13)

# %%
rev[1,0] = 14
rev
# Out:
# array([[10, 12,  9],
#        [14, 11, 13]])

# %%
rev.dtype
# Out:
# dtype('int64')

# %%
rev = np.array([[10,12,9],[15,11,13]], dtype=np.float64)
rev.dtype
# Out:
# dtype('float64')

# %% [markdown]
# item size means byte size of each element

# %%
rev.itemsize
# Out:
# 8

# %% [markdown]
# size means how many items are there

# %%
rev.size
# Out:
# 6

# %% [markdown]
# to identify the row and column

# %%
rev.shape
# Out:
# (2, 3)

# %% [markdown]
# sorting

# %%
rev
# Out:
# array([[10., 12.,  9.],
#        [15., 11., 13.]])

# %%
np.sort(rev)
# Out:
# array([[ 9., 10., 12.],
#        [11., 13., 15.]])

# %%
np.sort(rev, axis=None)
# Out:
# array([ 9., 10., 11., 12., 13., 15.])

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.arange(10,20,2)
# Out:
# array([10, 12, 14, 16, 18])

# %%
np.linspace(10,20, 5)
# Out:
# array([10. , 12.5, 15. , 17.5, 20. ])

# %%
rev.ravel()
# Out:
# array([10., 12.,  9., 15., 11., 13.])

# %%
rev
# Out:
# array([[10., 12.,  9.],
#        [15., 11., 13.]])

# %%
rev.flatten()
# Out:
# array([10., 12.,  9., 15., 11., 13.])

# %%
rev.reshape(3,2)
# Out:
# array([[10., 12.],
#        [ 9., 15.],
#        [11., 13.]])

# %%
rev.min()
# Out:
# np.float64(9.0)

# %%
rev.max()
# Out:
# np.float64(15.0)

# %% [markdown]
# get the sum in horizontically

# %%
rev.sum(axis=1)
# Out:
# array([31., 39.])

# %% [markdown]
# get the sum in vertically

# %%
rev.sum(axis=0)
# Out:
# array([25., 23., 22.])

# %%
rev
# Out:
# array([[10., 12.,  9.],
#        [15., 11., 13.]])

# %%
for row in rev:
    print("row:-> ", row)
# Out:
# row:->  [10. 12.  9.]
# row:->  [15. 11. 13.]

# %%
b = np.array([1,4,16])

# %%
np.sqrt(b)
# Out:
# array([1., 2., 4.])

# %%
np.square(b)
# Out:
# array([  1,  16, 256])

# %%
np.std(b)
# Out:
# np.float64(6.48074069840786)
